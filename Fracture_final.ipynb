# %% [markdown]
# <a href="https://colab.research.google.com/github/meet21039/EEE-GS-513--Machine-Learning-Course-Project/blob/main/Fracture_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import random
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers, losses, metrics, callbacks

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
IMG_SIZE = (128, 128)   # standard for transfer learning; reduce to (128,128) to save memory
BATCH_SIZE = 32
AUTOTUNE = tf.data.AUTOTUNE

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Cell 2 - Build dataframe of image paths and patient-level labels
DATA_DIR = "/content/drive/MyDrive/Train"   # change to your dataset folder in Colab
# Expect structure: DATA_DIR/patient_x/*.jpg (or png). Label could be in a labels.csv or inferred from folder name.

# Option A: If you have labels.csv with columns ['patient','label']
labels_csv = os.path.join(DATA_DIR, 'labels.csv')
if os.path.exists(labels_csv):
    labels_df = pd.read_csv(labels_csv)
    # assume 'patient' column matches folder names and label is 0/1
    rows = []
    for _, r in labels_df.iterrows():
        p = r['patient']
        lab = int(r['label'])
        pdir = Path(DATA_DIR) / str(p)
        if pdir.exists():
            for img in pdir.glob('*'):
                if img.suffix.lower() in ['.jpg','.jpeg','.png']:
                    rows.append({'patient': p, 'path': str(img), 'label': lab})
    df = pd.DataFrame(rows)
else:
    # Option B: infer label from patient folder name (e.g., patient_001_pos or contains 'yes','tumor','abnormal')
    rows = []
    for pdir in Path(DATA_DIR).iterdir():
        if pdir.is_dir():
            name = pdir.name.lower()
            if any(x in name for x in ['yes','tumor','abnormal','fracture','pos','positive']):
                lab = 1
            elif any(x in name for x in ['no','normal','neg','negative','healthy']):
                lab = 0
            else:
                # unknown, ask user or skip (we assume 0 by default - change as needed)
                lab = 0
            for img in pdir.glob('*'):
                if img.suffix.lower() in ['.jpg','.jpeg','.png','.png']:
                    rows.append({'patient': pdir.name, 'path': str(img), 'label': lab})
    df = pd.DataFrame(rows)

# quick stats
print("Total images:", len(df))
print("Unique patients:", df['patient'].nunique())
print(df)
# Out:
# Total images: 9756
# Unique patients: 2
#        patient                                               path  label
# 0     positive  /content/drive/MyDrive/Train/positive/patient0...      1
# 1     positive  /content/drive/MyDrive/Train/positive/patient0...      1
# 2     positive  /content/drive/MyDrive/Train/positive/patient0...      1
# 3     positive  /content/drive/MyDrive/Train/positive/patient0...      1
# 4     positive  /content/drive/MyDrive/Train/positive/patient0...      1
# ...        ...                                                ...    ...
# 9751  negative  /content/drive/MyDrive/Train/negative/patient0...      0
# 9752  negative  /content/drive/MyDrive/Train/negative/patient0...      0
# 9753  negative  /content/drive/MyDrive/Train/negative/patient0...      0
# 9754  negative  /content/drive/MyDrive/Train/negative/patient0...      0
# 9755  negative  /content/drive/MyDrive/Train/negative/patient0...      0
#
# [9756 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
from pathlib import Path

SEED = 42

# ---- Step 1: Train + Temp ----
train_df, temp_df = train_test_split(
    df,
    test_size=0.30,    # 20% test + 10% val = 30%
    stratify=df['label'],
    random_state=SEED
)

# ---- Step 2: Temp → Validation + Test ----
val_df, test_df = train_test_split(
    temp_df,
    test_size=2/3,     # because 20% test out of remaining 30% → (20/30 = 2/3)
    stratify=temp_df['label'],
    random_state=SEED
)

print("Train / Val / Test sizes:", len(train_df), len(val_df), len(test_df))

# ---- Save as CSV ----
out = Path("/content/drive/MyDrive/ML")
out.mkdir(exist_ok=True)

train_df.to_csv(out/"train.csv", index=False)
val_df.to_csv(out/"val.csv", index=False)
test_df.to_csv(out/"test.csv", index=False)

print("Saved CSVs to:", out)
# Out:
# Train / Val / Test sizes: 6829 975 1952
# Saved CSVs to: /content/drive/MyDrive/ML

# %%
# Cell 4 - preprocessing function (uses OpenCV)
IMG_H, IMG_W = IMG_SIZE

def read_and_preprocess(path, clahe=True):
    try:
        img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
        if img is None:
            raise ValueError("cv2.imread returned None")
        if clahe:
            clahe_op = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
            img = clahe_op.apply(img)
        img = cv2.resize(img, IMG_SIZE, interpolation=cv2.INTER_AREA)
        img = img.astype('float32') / 255.0
        img = np.stack([img, img, img], axis=-1)
        return img
    except Exception as e:
        print(" Error reading:", path, "Reason:", e)
        # return a blank image so TF pipeline doesn’t break
        return np.zeros((*IMG_SIZE, 3), dtype='float32')

# %%
# Cell 5 - tf.data pipeline creation
def df_to_tf_dataset(df, shuffle=True, augment=False):
    paths = df['path'].values
    labels = df['label'].astype('float32').values
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))
    if shuffle:
        ds = ds.shuffle(buffer_size=len(paths), seed=SEED)

    # load & preprocess using numpy_function for OpenCV
    def _load(path, label):
        img = tf.numpy_function(lambda p: read_and_preprocess(p.decode('utf-8')), [path], tf.float32)
        # Ensure the shape is set after the numpy function call
        img.set_shape((IMG_H, IMG_W, 3))
        return img, label

    # Filter out images that failed to load (returned None)
    # We can check for NaN values which might result from failed loading
    ds = ds.map(_load, num_parallel_calls=AUTOTUNE).filter(lambda img, label: tf.reduce_all(tf.math.is_finite(img)))


    if augment:
        aug = keras.Sequential([
            layers.RandomFlip("horizontal"),            # horizontal OK for most X-rays; verify for your task
            layers.RandomRotation(0.04),
            layers.RandomZoom(0.06),
        ])
        ds = ds.map(lambda x, y: (aug(x, training=True), y), num_parallel_calls=AUTOTUNE)
    ds = ds.batch(BATCH_SIZE).prefetch(AUTOTUNE)
    return ds

train_ds = df_to_tf_dataset(train_df, shuffle=True, augment=True)
test_ds  = df_to_tf_dataset(test_df, shuffle=False, augment=False)
val_ds  = df_to_tf_dataset(val_df, shuffle=False, augment=False)
# quick check — show a few images
for imgs, labs in train_ds.take(1):
    plt.figure(figsize=(10,6))
    for i in range(min(9, imgs.shape[0])):
        ax = plt.subplot(3,3,i+1)
        plt.imshow(imgs[i].numpy())
        plt.title(int(labs[i].numpy()))
        plt.axis('off')
    plt.show()
    print(test_ds)
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.float32, name=None))>

# %%
# Cell 6 - baseline CNN
def make_baseline_cnn(input_shape=(IMG_H, IMG_W, 3)):
    inp = layers.Input(shape=input_shape)
    x = layers.Conv2D(32, 3, padding='same', activation='relu')(inp)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D(2)(x)

    x = layers.Conv2D(64, 3, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D(2)(x)

    x = layers.Conv2D(128, 3, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D(2)(x)

    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.4)(x)
    out = layers.Dense(1, activation='sigmoid', dtype='float32')(x)
    model = models.Model(inp, out, name='baseline_cnn')
    return model

model = make_baseline_cnn()
model.compile(optimizer=optimizers.Adam(learning_rate=1e-3),
              loss=losses.BinaryCrossentropy(),
              metrics=[metrics.BinaryAccuracy(name='acc'), metrics.AUC(name='auc')])
model.summary()
# Out:
# Model: "baseline_cnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 94,273 (368.25 KB)
#  Trainable params: 93,825 (366.50 KB)
#  Non-trainable params: 448 (1.75 KB)

# %%
# Cell 7 - callbacks and compute class weights
checkpoint_path = "/content/drive/MyDrive/ML/final_fracture_model.keras"
cbs = [
    callbacks.ModelCheckpoint(filepath=checkpoint_path, monitor='val_auc', mode='max', save_best_only=True, verbose=1),
    callbacks.EarlyStopping(monitor='val_auc', mode='max', patience=6, restore_best_weights=True, verbose=1),
    callbacks.ReduceLROnPlateau(monitor='val_auc', mode='max', factor=0.5, patience=3, verbose=1)
]

# compute class weights (image-level)
counts = train_df['label'].value_counts().to_dict()  # e.g., {0: N0, 1: N1}
total = sum(counts.values())
class_weight = {int(k): total/(len(counts)*v) for k,v in counts.items()}
print("Train counts:", counts, "class_weight:", class_weight)
# Out:
# Train counts: {0: 4615, 1: 3189} class_weight: {0: 0.8455037919826652, 1: 1.2235810598933836}

# %%
# Cell 8 - train baseline
EPOCHS = 20
history = model.fit(train_ds,
                    epochs=EPOCHS,
                    callbacks=cbs,
                    class_weight=class_weight)
# Out:
# Epoch 1/20
#     110/Unknown 85s 678ms/step - acc: 0.5267 - auc: 0.5663 - loss: 0.7670❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image2.png Reason: cv2.imread returned None
#     162/Unknown 107s 596ms/step - acc: 0.5441 - auc: 0.5846 - loss: 0.7464❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image3.png Reason: cv2.imread returned None
#     201/Unknown 122s 559ms/step - acc: 0.5524 - auc: 0.5923 - loss: 0.7374❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study1_negative._image1.png Reason: cv2.imread returned None
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 143s 544ms/step - acc: 0.5588 - auc: 0.5980 - loss: 0.7305 - learning_rate: 0.0010
# Epoch 2/20
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:160: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# /usr/local/lib/python3.12/dist-packages/keras/src/callbacks/model_checkpoint.py:302: UserWarning: Can save best model only with val_auc available.
#   if self._should_save_model(epoch, batch, logs, filepath):
# /usr/local/lib/python3.12/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: acc,auc,loss
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.12/dist-packages/keras/src/callbacks/callback_list.py:145: UserWarning: Learning rate reduction is conditioned on metric `val_auc` which is not available. Available metrics are: acc,auc,loss,learning_rate.
#   callback.on_epoch_end(epoch, logs)
#  35/244 ━━━━━━━━━━━━━━━━━━━━ 1:24 402ms/step - acc: 0.5831 - auc: 0.6364 - loss: 0.6742❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study1_negative._image1.png Reason: cv2.imread returned None
# 138/244 ━━━━━━━━━━━━━━━━━━━━ 42s 398ms/step - acc: 0.5988 - auc: 0.6497 - loss: 0.6660❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image3.png Reason: cv2.imread returned None
# 228/244 ━━━━━━━━━━━━━━━━━━━━ 6s 397ms/step - acc: 0.6039 - auc: 0.6537 - loss: 0.6633❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image2.png Reason: cv2.imread returned None
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 99s 400ms/step - acc: 0.6044 - auc: 0.6541 - loss: 0.6631 - learning_rate: 0.0010
# Epoch 3/20
#  73/244 ━━━━━━━━━━━━━━━━━━━━ 1:07 395ms/step - acc: 0.6249 - auc: 0.6859 - loss: 0.6394❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image2.png Reason: cv2.imread returned None
# 103/244 ━━━━━━━━━━━━━━━━━━━━ 55s 396ms/step - acc: 0.6232 - auc: 0.6834 - loss: 0.6421❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study1_negative._image1.png Reason: cv2.imread returned None
# 118/244 ━━━━━━━━━━━━━━━━━━━━ 49s 392ms/step - acc: 0.6224 - auc: 0.6818 - loss: 0.6434❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image3.png Reason: cv2.imread returned None
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 96s 395ms/step - acc: 0.6207 - auc: 0.6753 - loss: 0.6472 - learning_rate: 0.0010
# Epoch 4/20
#  87/244 ━━━━━━━━━━━━━━━━━━━━ 1:00 386ms/step - acc: 0.6400 - auc: 0.6877 - loss: 0.6320❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study1_negative._image1.png Reason: cv2.imread returned None
# 138/244 ━━━━━━━━━━━━━━━━━━━━ 41s 395ms/step - acc: 0.6400 - auc: 0.6870 - loss: 0.6343❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image3.png Reason: cv2.imread returned None
# 239/244 ━━━━━━━━━━━━━━━━━━━━ 1s 396ms/step - acc: 0.6367 - auc: 0.6848 - loss: 0.6369❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image2.png Reason: cv2.imread returned None
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 142s 395ms/step - acc: 0.6364 - auc: 0.6846 - loss: 0.6371 - learning_rate: 0.0010
# Epoch 5/20
#  42/244 ━━━━━━━━━━━━━━━━━━━━ 1:19 393ms/step - acc: 0.6601 - auc: 0.7023 - loss: 0.6476❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study1_negative._image1.png Reason: cv2.imread returned None
#  70/244 ━━━━━━━━━━━━━━━━━━━━ 1:08 395ms/step - acc: 0.6535 - auc: 0.6999 - loss: 0.6453❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image2.png Reason: cv2.imread returned None
# 134/244 ━━━━━━━━━━━━━━━━━━━━ 43s 397ms/step - acc: 0.6453 - auc: 0.6939 - loss: 0.6441❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image3.png Reason: cv2.imread returned None
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 97s 397ms/step - acc: 0.6425 - auc: 0.6914 - loss: 0.6423 - learning_rate: 0.0010
# Epoch 6/20
#  53/244 ━━━━━━━━━━━━━━━━━━━━ 1:18 410ms/step - acc: 0.6439 - auc: 0.7056 - loss: 0.6225❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image3.png Reason: cv2.imread returned None
# 124/244 ━━━━━━━━━━━━━━━━━━━━ 48s 401ms/step - acc: 0.6465 - auc: 0.7035 - loss: 0.6262❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study1_negative._image1.png Reason: cv2.imread returned None
# 168/244 ━━━━━━━━━━━━━━━━━━━━ 30s 399ms/step - acc: 0.6477 - auc: 0.7037 - loss: 0.6269❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image2.png Reason: cv2.imread returned None
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 98s 402ms/step - acc: 0.6482 - auc: 0.7044 - loss: 0.6271 - learning_rate: 0.0010
# Epoch 7/20
# 160/244 ━━━━━━━━━━━━━━━━━━━━ 33s 400ms/step - acc: 0.6640 - auc: 0.7168 - loss: 0.6178❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image3.png Reason: cv2.imread returned None
# 181/244 ━━━━━━━━━━━━━━━━━━━━ 25s 398ms/step - acc: 0.6643 - auc: 0.7175 - loss: 0.6174❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study1_negative._image1.png Reason: cv2.imread returned None
# 229/244 ━━━━━━━━━━━━━━━━━━━━ 6s 401ms/step - acc: 0.6650 - auc: 0.7189 - loss: 0.6163❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image2.png Reason: cv2.imread returned None
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 97s 399ms/step - acc: 0.6650 - auc: 0.7192 - loss: 0.6160 - learning_rate: 0.0010
# Epoch 8/20
#  13/244 ━━━━━━━━━━━━━━━━━━━━ 1:25 370ms/step - acc: 0.6389 - auc: 0.6888 - loss: 0.6483❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image3.png Reason: cv2.imread returned None
# 134/244 ━━━━━━━━━━━━━━━━━━━━ 43s 395ms/step - acc: 0.6584 - auc: 0.7194 - loss: 0.6185❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image2.png Reason: cv2.imread returned None
# 144/244 ━━━━━━━━━━━━━━━━━━━━ 39s 393ms/step - acc: 0.6590 - auc: 0.7201 - loss: 0.6178❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study1_negative._image1.png Reason: cv2.imread returned None
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 96s 394ms/step - acc: 0.6621 - auc: 0.7242 - loss: 0.6136 - learning_rate: 0.0010
# Epoch 9/20
#   5/244 ━━━━━━━━━━━━━━━━━━━━ 2:07 534ms/step - acc: 0.6815 - auc: 0.7220 - loss: 0.6026❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image2.png Reason: cv2.imread returned None
#  15/244 ━━━━━━━━━━━━━━━━━━━━ 1:40 439ms/step - acc: 0.6625 - auc: 0.7009 - loss: 0.6311❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study1_negative._image1.png Reason: cv2.imread returned None
# 197/244 ━━━━━━━━━━━━━━━━━━━━ 18s 396ms/step - acc: 0.6813 - auc: 0.7366 - loss: 0.6022❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image3.png Reason: cv2.imread returned None
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 98s 400ms/step - acc: 0.6823 - auc: 0.7391 - loss: 0.6004 - learning_rate: 0.0010
# Epoch 10/20
#  33/244 ━━━━━━━━━━━━━━━━━━━━ 1:23 393ms/step - acc: 0.6729 - auc: 0.7336 - loss: 0.6095❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image2.png Reason: cv2.imread returned None
#  94/244 ━━━━━━━━━━━━━━━━━━━━ 59s 397ms/step - acc: 0.6899 - auc: 0.7498 - loss: 0.5915❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study1_negative._image1.png Reason: cv2.imread returned None
# 165/244 ━━━━━━━━━━━━━━━━━━━━ 31s 395ms/step - acc: 0.6960 - auc: 0.7560 - loss: 0.5848❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image3.png Reason: cv2.imread returned None
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 142s 397ms/step - acc: 0.6961 - auc: 0.7582 - loss: 0.5831 - learning_rate: 0.0010
# Epoch 11/20
#  25/244 ━━━━━━━━━━━━━━━━━━━━ 1:23 382ms/step - acc: 0.6935 - auc: 0.7602 - loss: 0.5864❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image2.png Reason: cv2.imread returned None
#  87/244 ━━━━━━━━━━━━━━━━━━━━ 1:02 398ms/step - acc: 0.6807 - auc: 0.7517 - loss: 0.5885❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study1_negative._image1.png Reason: cv2.imread returned None
# 144/244 ━━━━━━━━━━━━━━━━━━━━ 39s 399ms/step - acc: 0.6852 - auc: 0.7564 - loss: 0.5834❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image3.png Reason: cv2.imread returned None
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 142s 398ms/step - acc: 0.6899 - auc: 0.7612 - loss: 0.5786 - learning_rate: 0.0010
# Epoch 12/20
# 120/244 ━━━━━━━━━━━━━━━━━━━━ 48s 389ms/step - acc: 0.7074 - auc: 0.7693 - loss: 0.5658❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study1_negative._image1.png Reason: cv2.imread returned None
# 128/244 ━━━━━━━━━━━━━━━━━━━━ 44s 387ms/step - acc: 0.7072 - auc: 0.7699 - loss: 0.5658❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image2.png Reason: cv2.imread returned None
# 185/244 ━━━━━━━━━━━━━━━━━━━━ 23s 391ms/step - acc: 0.7060 - auc: 0.7710 - loss: 0.5669❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image3.png Reason: cv2.imread returned None
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 141s 394ms/step - acc: 0.7065 - auc: 0.7723 - loss: 0.5664 - learning_rate: 0.0010
# Epoch 13/20
#   9/244 ━━━━━━━━━━━━━━━━━━━━ 1:25 363ms/step - acc: 0.7168 - auc: 0.8422 - loss: 0.5001❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image3.png Reason: cv2.imread returned None
#  44/244 ━━━━━━━━━━━━━━━━━━━━ 1:17 389ms/step - acc: 0.7130 - auc: 0.8135 - loss: 0.5261❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study1_negative._image1.png Reason: cv2.imread returned None
# 148/244 ━━━━━━━━━━━━━━━━━━━━ 37s 393ms/step - acc: 0.7125 - auc: 0.7960 - loss: 0.5438❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image2.png Reason: cv2.imread returned None
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 142s 394ms/step - acc: 0.7150 - auc: 0.7950 - loss: 0.5447 - learning_rate: 0.0010
# Epoch 14/20
# 104/244 ━━━━━━━━━━━━━━━━━━━━ 55s 395ms/step - acc: 0.7094 - auc: 0.7859 - loss: 0.5584❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study1_negative._image1.png Reason: cv2.imread returned None
# 107/244 ━━━━━━━━━━━━━━━━━━━━ 53s 394ms/step - acc: 0.7099 - auc: 0.7863 - loss: 0.5579❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image2.png Reason: cv2.imread returned None
# 193/244 ━━━━━━━━━━━━━━━━━━━━ 20s 397ms/step - acc: 0.7182 - auc: 0.7918 - loss: 0.5495❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image3.png Reason: cv2.imread returned None
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 96s 394ms/step - acc: 0.7207 - auc: 0.7932 - loss: 0.5473 - learning_rate: 0.0010
# Epoch 15/20
#   6/244 ━━━━━━━━━━━━━━━━━━━━ 1:28 371ms/step - acc: 0.7130 - auc: 0.7734 - loss: 0.5765❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image3.png Reason: cv2.imread returned None
# 170/244 ━━━━━━━━━━━━━━━━━━━━ 29s 396ms/step - acc: 0.7145 - auc: 0.7940 - loss: 0.5456❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image2.png Reason: cv2.imread returned None
# 197/244 ━━━━━━━━━━━━━━━━━━━━ 18s 397ms/step - acc: 0.7158 - auc: 0.7949 - loss: 0.5443❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study1_negative._image1.png Reason: cv2.imread returned None
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 143s 398ms/step - acc: 0.7185 - auc: 0.7963 - loss: 0.5423 - learning_rate: 0.0010
# Epoch 16/20
#  96/244 ━━━━━━━━━━━━━━━━━━━━ 58s 395ms/step - acc: 0.7467 - auc: 0.8106 - loss: 0.5257❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study1_negative._image1.png Reason: cv2.imread returned None
# 115/244 ━━━━━━━━━━━━━━━━━━━━ 51s 399ms/step - acc: 0.7450 - auc: 0.8097 - loss: 0.5267❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image3.png Reason: cv2.imread returned None
# 143/244 ━━━━━━━━━━━━━━━━━━━━ 40s 398ms/step - acc: 0.7441 - auc: 0.8092 - loss: 0.5277❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image2.png Reason: cv2.imread returned None
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 142s 397ms/step - acc: 0.7420 - auc: 0.8076 - loss: 0.5311 - learning_rate: 0.0010
# Epoch 17/20
#  41/244 ━━━━━━━━━━━━━━━━━━━━ 1:18 388ms/step - acc: 0.7553 - auc: 0.8237 - loss: 0.5140❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image3.png Reason: cv2.imread returned None
#  76/244 ━━━━━━━━━━━━━━━━━━━━ 1:05 391ms/step - acc: 0.7572 - auc: 0.8225 - loss: 0.5152❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study1_negative._image1.png Reason: cv2.imread returned None
# 161/244 ━━━━━━━━━━━━━━━━━━━━ 32s 391ms/step - acc: 0.7560 - auc: 0.8194 - loss: 0.5183❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image2.png Reason: cv2.imread returned None
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 97s 395ms/step - acc: 0.7532 - auc: 0.8173 - loss: 0.5203 - learning_rate: 0.0010
# Epoch 18/20
#  37/244 ━━━━━━━━━━━━━━━━━━━━ 1:21 393ms/step - acc: 0.7262 - auc: 0.8079 - loss: 0.5185❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image2.png Reason: cv2.imread returned None
# 126/244 ━━━━━━━━━━━━━━━━━━━━ 46s 394ms/step - acc: 0.7298 - auc: 0.8072 - loss: 0.5241❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image3.png Reason: cv2.imread returned None
# 130/244 ━━━━━━━━━━━━━━━━━━━━ 45s 397ms/step - acc: 0.7301 - auc: 0.8074 - loss: 0.5241❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study1_negative._image1.png Reason: cv2.imread returned None
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 141s 394ms/step - acc: 0.7354 - auc: 0.8112 - loss: 0.5221 - learning_rate: 0.0010
# Epoch 19/20
#  57/244 ━━━━━━━━━━━━━━━━━━━━ 1:15 403ms/step - acc: 0.7487 - auc: 0.8232 - loss: 0.5036❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image3.png Reason: cv2.imread returned None
# 167/244 ━━━━━━━━━━━━━━━━━━━━ 30s 396ms/step - acc: 0.7509 - auc: 0.8241 - loss: 0.5079❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image2.png Reason: cv2.imread returned None
# 178/244 ━━━━━━━━━━━━━━━━━━━━ 26s 394ms/step - acc: 0.7507 - auc: 0.8239 - loss: 0.5082❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study1_negative._image1.png Reason: cv2.imread returned None
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 96s 395ms/step - acc: 0.7498 - auc: 0.8228 - loss: 0.5101 - learning_rate: 0.0010
# Epoch 20/20
#  14/244 ━━━━━━━━━━━━━━━━━━━━ 1:41 440ms/step - acc: 0.7480 - auc: 0.8335 - loss: 0.5100❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study1_negative._image1.png Reason: cv2.imread returned None
# 154/244 ━━━━━━━━━━━━━━━━━━━━ 35s 399ms/step - acc: 0.7492 - auc: 0.8189 - loss: 0.5190❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image3.png Reason: cv2.imread returned None
# 226/244 ━━━━━━━━━━━━━━━━━━━━ 7s 397ms/step - acc: 0.7497 - auc: 0.8197 - loss: 0.5173❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image2.png Reason: cv2.imread returned None
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 98s 399ms/step - acc: 0.7498 - auc: 0.8199 - loss: 0.5169 - learning_rate: 0.0010

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Train')
plt.title('Loss'); plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['acc'], label='Train')
plt.title('Accuracy'); plt.legend()
plt.show()

# %%
# Cell 10 - image-level evaluation
test_res = model.evaluate(test_ds, verbose=1)
print("Test (loss, acc, auc):", test_res)

# detailed report
y_true = np.concatenate([y.numpy() for x,y in test_ds], axis=0)
y_probs = model.predict(test_ds)
y_pred = (y_probs.ravel() > 0.5).astype(int)

print(classification_report(y_true, y_pred, digits=4))
print("Confusion matrix:\n", confusion_matrix(y_true, y_pred))
try:
    print("ROC AUC:", roc_auc_score(y_true, y_probs))
except Exception as e:
    print("AUC error:", e)
# Out:
#      38/Unknown 11s 299ms/step - acc: 0.7484 - auc: 0.8359 - loss: 0.5193❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image1.png Reason: cv2.imread returned None
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 18s 289ms/step - acc: 0.7452 - auc: 0.8315 - loss: 0.5226
# Test (loss, acc, auc): [0.5278760194778442, 0.7336065769195557, 0.8213911056518555]
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:160: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# ❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image1.png Reason: cv2.imread returned None
#      38/Unknown 11s 288ms/step❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image1.png Reason: cv2.imread returned None
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 17s 285ms/step
#               precision    recall  f1-score   support
#
#          0.0     0.7856    0.7556    0.7703      1154
#          1.0     0.6651    0.7018    0.6829       798
#
#     accuracy                         0.7336      1952
#    macro avg     0.7253    0.7287    0.7266      1952
# weighted avg     0.7363    0.7336    0.7346      1952
#
# Confusion matrix:
#  [[872 282]
#  [238 560]]
# ROC AUC: 0.8214524613092522

# %%
import seaborn as sns
cm=confusion_matrix(y_true, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
base = keras.applications.EfficientNetB0(
    include_top=False,
    weights='imagenet',
    input_shape=IMG_SIZE + (3,)
)
base.trainable = False

inp = layers.Input(shape=IMG_SIZE + (3,))
x = base(inp, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.4)(x)
out = layers.Dense(len(class_names_xr), activation='softmax')(x)
xr_model = models.Model(inp, out, name='EffNet_XR')

xr_model.compile(
    optimizer=optimizers.Adam(1e-3),
    loss=losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']   # <- remove tf.keras.metrics.AUC
)

xr_model.summary()

xr_checkpoint = "/content/xray_best_model.keras"
xr_cb = [
    callbacks.ModelCheckpoint(
        xr_checkpoint,
        monitor='val_accuracy',   # <- monitor accuracy now
        mode='max',
        save_best_only=True,
        verbose=1
    ),
    callbacks.EarlyStopping(
        monitor='val_accuracy',
        mode='max',
        patience=5,
        restore_best_weights=True
    )
]

# ---- Train head ----
xr_model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=6,
    callbacks=xr_cb
)

# ---- Fine-tune ----
base.trainable = True
for layer in base.layers[:-20]:
    layer.trainable = False

xr_model.compile(
    optimizer=optimizers.Adam(1e-5),
    loss=losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']   # still no AUC
)

xr_model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=8,
    callbacks=xr_cb
)

xr_model.save("/content/xray_final_model.keras")
print("✅ Training done & model saved.")
# Out:
# Model: "EffNet_XR"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_15 (InputLayer)     │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 4, 4, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_5      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 2)              │         2,562 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,052,133 (15.46 MB)
#  Trainable params: 2,562 (10.01 KB)
#  Non-trainable params: 4,049,571 (15.45 MB)
# Epoch 1/6
#       7/Unknown 61s 3s/step - accuracy: 0.6306 - loss: 0.6807❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study1_negative._image1.png Reason: cv2.imread returned None
#      21/Unknown 136s 5s/step - accuracy: 0.5989 - loss: 0.6869❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image2.png Reason: cv2.imread returned None
#     182/Unknown 1052s 6s/step - accuracy: 0.5634 - loss: 0.6960❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image3.png Reason: cv2.imread returned None
#     214/Unknown 1256s 6s/step - accuracy: 0.5640 - loss: 0.6956
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:160: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 1: val_accuracy improved from -inf to 0.59179, saving model to /content/xray_best_model.keras
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1448s 7s/step - accuracy: 0.5640 - loss: 0.6956 - val_accuracy: 0.5918 - val_loss: 0.6764
# Epoch 2/6
#  10/214 ━━━━━━━━━━━━━━━━━━━━ 1:21 402ms/step - accuracy: 0.5159 - loss: 0.6771❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image2.png Reason: cv2.imread returned None
#  24/214 ━━━━━━━━━━━━━━━━━━━━ 1:15 399ms/step - accuracy: 0.5176 - loss: 0.6866❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study1_negative._image1.png Reason: cv2.imread returned None
# 135/214 ━━━━━━━━━━━━━━━━━━━━ 34s 434ms/step - accuracy: 0.5573 - loss: 0.6885❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image3.png Reason: cv2.imread returned None
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step - accuracy: 0.5602 - loss: 0.6900
# Epoch 2: val_accuracy did not improve from 0.59179
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 103s 479ms/step - accuracy: 0.5602 - loss: 0.6900 - val_accuracy: 0.5918 - val_loss: 0.7012
# Epoch 3/6
#  94/214 ━━━━━━━━━━━━━━━━━━━━ 52s 440ms/step - accuracy: 0.5746 - loss: 0.6876❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image2.png Reason: cv2.imread returned None
# 107/214 ━━━━━━━━━━━━━━━━━━━━ 47s 446ms/step - accuracy: 0.5736 - loss: 0.6880❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study1_negative._image1.png Reason: cv2.imread returned None
# 110/214 ━━━━━━━━━━━━━━━━━━━━ 46s 445ms/step - accuracy: 0.5735 - loss: 0.6881❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image3.png Reason: cv2.imread returned None
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - accuracy: 0.5707 - loss: 0.6893
# Epoch 3: val_accuracy did not improve from 0.59179
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 104s 484ms/step - accuracy: 0.5707 - loss: 0.6893 - val_accuracy: 0.5918 - val_loss: 0.6806
# Epoch 4/6
# 136/214 ━━━━━━━━━━━━━━━━━━━━ 34s 436ms/step - accuracy: 0.5460 - loss: 0.7011❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study1_negative._image1.png Reason: cv2.imread returned None
# 141/214 ━━━━━━━━━━━━━━━━━━━━ 32s 439ms/step - accuracy: 0.5465 - loss: 0.7008❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image2.png Reason: cv2.imread returned None
# 143/214 ━━━━━━━━━━━━━━━━━━━━ 31s 441ms/step - accuracy: 0.5466 - loss: 0.7007❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image3.png Reason: cv2.imread returned None
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - accuracy: 0.5509 - loss: 0.6983
# Epoch 4: val_accuracy did not improve from 0.59179
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 103s 482ms/step - accuracy: 0.5510 - loss: 0.6983 - val_accuracy: 0.5918 - val_loss: 0.6944
# Epoch 5/6
#   5/214 ━━━━━━━━━━━━━━━━━━━━ 1:26 416ms/step - accuracy: 0.6285 - loss: 0.6774❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image3.png Reason: cv2.imread returned None
#  33/214 ━━━━━━━━━━━━━━━━━━━━ 1:18 436ms/step - accuracy: 0.6165 - loss: 0.6726❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study1_negative._image1.png Reason: cv2.imread returned None
#  71/214 ━━━━━━━━━━━━━━━━━━━━ 1:02 435ms/step - accuracy: 0.5894 - loss: 0.6791❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image2.png Reason: cv2.imread returned None
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5775 - loss: 0.6822
# Epoch 5: val_accuracy did not improve from 0.59179
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 281s 1s/step - accuracy: 0.5775 - loss: 0.6822 - val_accuracy: 0.5918 - val_loss: 0.6793
# Epoch 6/6
#  53/214 ━━━━━━━━━━━━━━━━━━━━ 1:26 535ms/step - accuracy: 0.5506 - loss: 0.6863❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image3.png Reason: cv2.imread returned None
#  92/214 ━━━━━━━━━━━━━━━━━━━━ 2:17 1s/step - accuracy: 0.5562 - loss: 0.6859❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image2.png Reason: cv2.imread returned None
# 210/214 ━━━━━━━━━━━━━━━━━━━━ 3s 807ms/step - accuracy: 0.5660 - loss: 0.6857❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study1_negative._image1.png Reason: cv2.imread returned None
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 802ms/step - accuracy: 0.5661 - loss: 0.6857
# Epoch 6: val_accuracy did not improve from 0.59179
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 183s 856ms/step - accuracy: 0.5661 - loss: 0.6856 - val_accuracy: 0.5785 - val_loss: 0.6923
# Epoch 1/8
#      51/Unknown 90s 919ms/step - accuracy: 0.5061 - loss: 0.7514❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study1_negative._image1.png Reason: cv2.imread returned None
#     161/Unknown 137s 577ms/step - accuracy: 0.5266 - loss: 0.7276❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image2.png Reason: cv2.imread returned None
#     164/Unknown 138s 574ms/step - accuracy: 0.5269 - loss: 0.7273❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image3.png Reason: cv2.imread returned None
#     214/Unknown 173s 602ms/step - accuracy: 0.5311 - loss: 0.7228
# Epoch 1: val_accuracy did not improve from 0.59179
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 193s 699ms/step - accuracy: 0.5312 - loss: 0.7227 - val_accuracy: 0.5918 - val_loss: 0.6923
# Epoch 2/8
# 123/214 ━━━━━━━━━━━━━━━━━━━━ 38s 425ms/step - accuracy: 0.5769 - loss: 0.6909❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study1_negative._image1.png Reason: cv2.imread returned None
# 139/214 ━━━━━━━━━━━━━━━━━━━━ 32s 429ms/step - accuracy: 0.5761 - loss: 0.6907❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image2.png Reason: cv2.imread returned None
# 157/214 ━━━━━━━━━━━━━━━━━━━━ 24s 424ms/step - accuracy: 0.5754 - loss: 0.6906❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image3.png Reason: cv2.imread returned None
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.5743 - loss: 0.6905
# Epoch 2: val_accuracy did not improve from 0.59179
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 101s 474ms/step - accuracy: 0.5743 - loss: 0.6905 - val_accuracy: 0.5918 - val_loss: 0.6771
# Epoch 3/8
#  88/214 ━━━━━━━━━━━━━━━━━━━━ 58s 468ms/step - accuracy: 0.5515 - loss: 0.6954❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image2.png Reason: cv2.imread returned None
# 143/214 ━━━━━━━━━━━━━━━━━━━━ 32s 462ms/step - accuracy: 0.5569 - loss: 0.6942❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study1_negative._image1.png Reason: cv2.imread returned None
# 187/214 ━━━━━━━━━━━━━━━━━━━━ 12s 453ms/step - accuracy: 0.5588 - loss: 0.6941❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image3.png Reason: cv2.imread returned None
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - accuracy: 0.5597 - loss: 0.6940
# Epoch 3: val_accuracy did not improve from 0.59179
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 108s 506ms/step - accuracy: 0.5597 - loss: 0.6940 - val_accuracy: 0.5918 - val_loss: 0.6786
# Epoch 4/8
# 100/214 ━━━━━━━━━━━━━━━━━━━━ 52s 463ms/step - accuracy: 0.5715 - loss: 0.6948❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study1_negative._image1.png Reason: cv2.imread returned None
# 175/214 ━━━━━━━━━━━━━━━━━━━━ 18s 469ms/step - accuracy: 0.5692 - loss: 0.6944❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image3.png Reason: cv2.imread returned None
# 182/214 ━━━━━━━━━━━━━━━━━━━━ 14s 468ms/step - accuracy: 0.5690 - loss: 0.6944❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image2.png Reason: cv2.imread returned None
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.5685 - loss: 0.6944
# Epoch 4: val_accuracy did not improve from 0.59179
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 111s 517ms/step - accuracy: 0.5685 - loss: 0.6944 - val_accuracy: 0.5918 - val_loss: 0.6739
# Epoch 5/8
#  25/214 ━━━━━━━━━━━━━━━━━━━━ 1:33 497ms/step - accuracy: 0.5987 - loss: 0.6720❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image2.png Reason: cv2.imread returned None
#  50/214 ━━━━━━━━━━━━━━━━━━━━ 1:21 496ms/step - accuracy: 0.5958 - loss: 0.6741❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image3.png Reason: cv2.imread returned None
# 124/214 ━━━━━━━━━━━━━━━━━━━━ 42s 477ms/step - accuracy: 0.5900 - loss: 0.6769❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study1_negative._image1.png Reason: cv2.imread returned None
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.5863 - loss: 0.6789
# Epoch 5: val_accuracy did not improve from 0.59179
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 111s 518ms/step - accuracy: 0.5862 - loss: 0.6789 - val_accuracy: 0.5918 - val_loss: 0.6735
# Epoch 6/8
# 197/214 ━━━━━━━━━━━━━━━━━━━━ 8s 477ms/step - accuracy: 0.5734 - loss: 0.6874❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study1_negative._image1.png Reason: cv2.imread returned None
# 200/214 ━━━━━━━━━━━━━━━━━━━━ 6s 476ms/step - accuracy: 0.5734 - loss: 0.6874❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image2.png Reason: cv2.imread returned None
# 208/214 ━━━━━━━━━━━━━━━━━━━━ 2s 473ms/step - accuracy: 0.5733 - loss: 0.6874❌ Error reading: /content/drive/MyDrive/Train/negative/patient07840study2_negative._image3.png Reason: cv2.imread returned None
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step - accuracy: 0.5733 - loss: 0.6873
# Epoch 6: val_accuracy did not improve from 0.59179
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 112s 521ms/step - accuracy: 0.5733 - loss: 0.6873 - val_accuracy: 0.5918 - val_loss: 0.6731
# ✅ Training done & model saved.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras.applications.efficientnet import preprocess_input

# ---------------- DEFINE GRAD-CAM FUNCTION ----------------
def find_last_conv_in_base(base_model):
    for layer in reversed(base_model.layers):
        if isinstance(layer, layers.Conv2D):
            return layer.name
    raise ValueError("No Conv2D layer found in the base model.")

def make_gradcam_heatmap_working(img_array, full_model, pred_index=None):
    # Find nested CNN base
    base = None
    for layer in full_model.layers:
        if hasattr(layer, "layers") and len(layer.layers) > 0:
            base = layer
            break

    last_conv_name = find_last_conv_in_base(base)
    last_conv = base.get_layer(last_conv_name)

    conv_model = tf.keras.Model(inputs=base.input, outputs=last_conv.output)

    img_tensor = tf.cast(img_array, tf.float32)
    conv_outs = conv_model(img_tensor, training=False)

    # Forward through model head manually
    base_idx = [i for i, l in enumerate(full_model.layers) if l is base][0]

    x = conv_outs
    for layer in full_model.layers[base_idx+1:]:
        try:
            x = layer(x, training=False)
        except:
            x = layer(x)

    preds = x

    if pred_index is None:
        pred_index = int(tf.argmax(preds[0]))

    with tf.GradientTape() as tape:
        tape.watch(conv_outs)
        x2 = conv_outs
        for layer in full_model.layers[base_idx+1:]:
            try:
                x2 = layer(x2, training=False)
            except:
                x2 = layer(x2)
        preds2 = x2
        class_score = preds2[:, pred_index]

    grads = tape.gradient(class_score, conv_outs)
    pooled = tf.reduce_mean(grads, axis=(0,1,2)).numpy()

    cam = np.sum(conv_outs[0].numpy() * pooled[None,None,:], axis=-1)
    cam = np.maximum(cam, 0)
    cam /= (cam.max() + 1e-8)

    heatmap = cv2.resize(cam, (img_array.shape[2], img_array.shape[1]))
    return heatmap

# ---------------- PARAMETERS ----------------
class_names = ['fracture','nofracture']
THR_PERCENTILE = 85
ALPHA_HEAT = 0.5
ALPHA_MASK = 0.65
MIN_AREA = 200
SAVE_PATH = "/content/final_gradcam_highlight.png"
sample_path = "/content/drive/MyDrive/Train/positive/patient07429study1_positiveimage3.png"
# ---------------- INPUT IMAGE ----------------
img_bgr = cv2.imread(sample_path)
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
img_resized = cv2.resize(img_rgb, (IMG_SIZE[1], IMG_SIZE[0]))

img_pre = preprocess_input(img_resized.astype('float32'))
img_input = np.expand_dims(img_pre, axis=0)

# ---------------- PREDICT ----------------
preds = xr_model.predict(img_input)
pred_idx = int(np.argmax(preds[0]))
pred_class = class_names[pred_idx]

print("\n🔹 MODEL OUTPUT 🔹")
print(f"Predicted Index: {pred_idx}")
print(f"Predicted Class: {pred_class}")
print(f"Confidence: {preds[0][pred_idx]:.4f}")

print("\nClass probability breakdown:")
for i, c in enumerate(class_names):
    print(f"  {i} → {c}: {preds[0][i]:.4f}")

# ---------------- GENERATE HEATMAP ----------------
heatmap = make_gradcam_heatmap_working(img_input, xr_model)

# refine
hm = cv2.GaussianBlur((heatmap * 255).astype(np.uint8), (11,11), 0).astype(np.float32)/255.
thr = np.percentile(hm, THR_PERCENTILE)
hm_thr = np.clip((hm - thr) / (hm.max() - thr + 1e-8), 0, 1)

mask_uint8 = (hm_thr * 255).astype(np.uint8)
contours, _ = cv2.findContours(mask_uint8, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

overlay = img_resized.copy()

if contours:
    contours = sorted(contours, key=cv2.contourArea, reverse=True)
    cnt = contours[0]

    if cv2.contourArea(cnt) > MIN_AREA:
        cv2.drawContours(overlay, [cnt], -1, (255, 0, 0), 3)
        x,y,w,h = cv2.boundingRect(cnt)
        cv2.rectangle(overlay, (x,y), (x+w,y+h), (255,255,255), 4)

heatmap_color = cv2.applyColorMap((hm_thr*255).astype(np.uint8), cv2.COLORMAP_JET)
blended = cv2.addWeighted(img_resized, 1-ALPHA_HEAT, heatmap_color, ALPHA_HEAT, 0)

# ---------------- SAVE & DISPLAY ----------------
final = cv2.addWeighted(blended, 1-ALPHA_MASK, overlay, ALPHA_MASK, 0)

plt.figure(figsize=(10,5))
plt.imshow(final)
plt.axis('off')
plt.title(f"Grad-CAM Highlight → {pred_class} ({preds[0][pred_idx]:.2f})")

cv2.imwrite(SAVE_PATH, cv2.cvtColor(final, cv2.COLOR_RGB2BGR))
print(f"\n Saved final Grad-CAM to: {SAVE_PATH}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#
# 🔹 MODEL OUTPUT 🔹
# Predicted Index: 0
# Predicted Class: fracture
# Confidence: 0.6687
#
# Class probability breakdown:
#   0 → fracture: 0.6687
#   1 → nofracture: 0.3313
#
# 📁 Saved final Grad-CAM to: /content/final_gradcam_highlight.png
